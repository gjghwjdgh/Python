# %%
import matplotlib.pyplot as plt
a = [10, 20, 30, 40]
b = ["korean", "English", "math", "info"]
plt.plot(b,a,'r:')
plt.ylabel('some numbers')
# Out:
# Text(0, 0.5, 'some numbers')

# %%
import matplotlib.pyplot as plt
a = [10, -20, 30, 40]
c = [10, -20, 30, 40]
b = ["korean", "English", "math", "info"]
plt.bar(b,a,color = "lightblue")
plt.plot(b,c,color="pink")
plt.ylabel('jumsu')
plt.xlabel("subject")
plt.title("Score")
plt.legend('value')
